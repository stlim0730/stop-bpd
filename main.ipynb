# %%
# Taek / Oct 19
# Proof of concept for Berkeley Police Department Stop Data
import sys
import datascience
import folium

def file_to_dict(file_obj, delimeter):
  '''
  takes a data file object (delimetered) and returns the dataset as a list of dictionary
  '''
  line = file_obj.readline().strip()
  res = []
  keys = []
  if line != '':
    keys = line.split(delimeter)
  if len(keys) == 0:
    print('Invalid input (no column names found).')
    sys.exit(1)
  line = file_obj.readline().strip()
  cnt = 0
  while line != '':
    cnt += 1
    vals = line.split(delimeter)
    val_len = len(vals)
    if len(keys) != val_len:
      print('Invalid input (# of columns). - ' + str(cnt))
      sys.exit(1)
    record = {}
    for i in range(val_len):
      record[keys[i]] = vals[i].strip()
    res.append(record)
    line = file_obj.readline().strip()
  print('Read ' + str(len(res)) + ' records from file.')
  return res

# %%
f_name = 'data.txt'
f = open(f_name, 'r')
d = file_to_dict(f, '|')
t = datascience.Table.from_records(d)
t.show(10) # displaying ten rows
# Out:
# Read 8102 records from file.
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>address</th> <th>date</th> <th>dispositions</th> <th>incident_number</th> <th>incident_type</th> <th>lat</th> <th>long</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>SAN PABLO AVE AND MARIN AVE, BERKELEY, CA                 </td> <td>1/26/15 0:10 </td> <td>M           </td> <td>2015-00004825  </td> <td>Traffic      </td> <td>37.8867034</td> <td>-122.2978679</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>SAN PABLO AVE AND CHANNING WAY, BERKELEY, CA              </td> <td>1/26/15 0:50 </td> <td>M           </td> <td>2015-00004829  </td> <td>Traffic      </td> <td>37.862872 </td> <td>-122.2900545</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>UNIVERSITY AVE AND NINTH ST, BERKELEY, CA                 </td> <td>1/26/15 1:03 </td> <td>M           </td> <td>2015-00004831  </td> <td>Traffic      </td> <td>37.8687133</td> <td>-122.2944035</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2000 BERKELEY WAY, BERKELEY, CA                           </td> <td>1/26/15 7:16 </td> <td>BM4ICN      </td> <td>2015-00004848  </td> <td>Pedestrian   </td> <td>37.8734511</td> <td>-122.2706227</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1700 SAN PABLO AVE, BERKELEY, CA                          </td> <td>1/26/15 7:43 </td> <td>BM4ICN      </td> <td>2015-00004849  </td> <td>Pedestrian   </td> <td>37.8731719</td> <td>-122.293804 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MARTIN LUTHER KING JR WAY AND UNIVERSITY AVE, BERKELEY, CA</td> <td>1/26/15 9:46 </td> <td>OF4TCN      </td> <td>2015-00004865  </td> <td>Traffic      </td> <td>37.8716087</td> <td>-122.2730269</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MARTIN LUTHER KING JR WAY AND UNIVERSITY AVE, BERKELEY, CA</td> <td>1/26/15 10:05</td> <td>OM4TCN      </td> <td>2015-00004870  </td> <td>Traffic      </td> <td>37.8716087</td> <td>-122.2730269</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>UNIVERSITY AVE AND MARTIN LUTHER KING JR WAY, BERKELEY, CA</td> <td>1/26/15 10:21</td> <td>OF2TCN      </td> <td>2015-00004876  </td> <td>Traffic      </td> <td>37.8716087</td> <td>-122.2730269</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>HASTE ST AND ELLSWORTH ST, BERKELEY, CA                   </td> <td>1/26/15 10:49</td> <td>OM2TCN      </td> <td>2015-00004882  </td> <td>Traffic      </td> <td>37.8654442</td> <td>-122.2631606</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ADELINE ST AND OREGON ST, BERKELEY, CA                    </td> <td>1/26/15 11:12</td> <td>OM2TCN      </td> <td>2015-00004887  </td> <td>Traffic      </td> <td>37.857428 </td> <td>-122.2682845</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (8092 rows omitted)</p

# %%
# Playing with table-related methods in datascience package
t.stats()
# Out:
# <Table(8 rows): | statistic | address | date | dispositions | incident_number | incident_type | lat | long |>

# %%
# The summary above shows that there are missing values; min values with empty strings.
t.select(['incident_type', 'dispositions', 'address']) # Projection for selected columns
# Out:
# <Table(3 rows): | incident_type | dispositions | address |>

# %%
t.sort('incident_number', True) # The second parameter means descending order. It creates a new table sorted.
# Out:
# <Table(7 rows): | address | date | dispositions | incident_number | incident_type | lat | long |>

# %%
t.hist() # Plotting histograms for the columns
# Drawing capability requires further preprocessing; see the error message below
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-7bc7abccb8a8> in <module>()
# ----> 1 t.hist() # Plotting histograms for the columns
#       2 # Drawing capability requires further preprocessing; see the error message below
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/datascience/tables.py in hist(self, overlay, bins, counts, **vargs)
#    1076                 raise ValueError("The column '{0}' contains non-numerical "
#    1077                     "values. A histogram cannot be drawn for this table."
# -> 1078                     .format(col))
#    1079
#    1080         columns = self._columns.copy()
#
# ValueError: The column 'address' contains non-numerical values. A histogram cannot be drawn for this table.

# %%
# Stop playing with Table-related methods in datascience package

NUM_SAMPLES = 4455
sub_table = t.take(range(4455)) # selecting the first 4455 rows because they have lat/long
# sample_table = sub_table.sample([NUM_SAMPLES]) # randomly sampling

# %%
sub_table.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>address</th> <th>date</th> <th>dispositions</th> <th>incident_number</th> <th>incident_type</th> <th>lat</th> <th>long</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>SAN PABLO AVE AND MARIN AVE, BERKELEY, CA                  </td> <td>1/26/15 0:10 </td> <td>M                                     </td> <td>2015-00004825  </td> <td>Traffic           </td> <td>37.8867034 </td> <td>-122.2978679</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>SAN PABLO AVE AND CHANNING WAY, BERKELEY, CA               </td> <td>1/26/15 0:50 </td> <td>M                                     </td> <td>2015-00004829  </td> <td>Traffic           </td> <td>37.862872  </td> <td>-122.2900545</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>UNIVERSITY AVE AND NINTH ST, BERKELEY, CA                  </td> <td>1/26/15 1:03 </td> <td>M                                     </td> <td>2015-00004831  </td> <td>Traffic           </td> <td>37.8687133 </td> <td>-122.2944035</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2000 BERKELEY WAY, BERKELEY, CA                            </td> <td>1/26/15 7:16 </td> <td>BM4ICN                                </td> <td>2015-00004848  </td> <td>Pedestrian        </td> <td>37.8734511 </td> <td>-122.2706227</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1700 SAN PABLO AVE, BERKELEY, CA                           </td> <td>1/26/15 7:43 </td> <td>BM4ICN                                </td> <td>2015-00004849  </td> <td>Pedestrian        </td> <td>37.8731719 </td> <td>-122.293804 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MARTIN LUTHER KING JR WAY AND UNIVERSITY AVE, BERKELEY, CA </td> <td>1/26/15 9:46 </td> <td>OF4TCN                                </td> <td>2015-00004865  </td> <td>Traffic           </td> <td>37.8716087 </td> <td>-122.2730269</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MARTIN LUTHER KING JR WAY AND UNIVERSITY AVE, BERKELEY, CA </td> <td>1/26/15 10:05</td> <td>OM4TCN                                </td> <td>2015-00004870  </td> <td>Traffic           </td> <td>37.8716087 </td> <td>-122.2730269</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>UNIVERSITY AVE AND MARTIN LUTHER KING JR WAY, BERKELEY, CA </td> <td>1/26/15 10:21</td> <td>OF2TCN                                </td> <td>2015-00004876  </td> <td>Traffic           </td> <td>37.8716087 </td> <td>-122.2730269</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>HASTE ST AND ELLSWORTH ST, BERKELEY, CA                    </td> <td>1/26/15 10:49</td> <td>OM2TCN                                </td> <td>2015-00004882  </td> <td>Traffic           </td> <td>37.8654442 </td> <td>-122.2631606</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ADELINE ST AND OREGON ST, BERKELEY, CA                     </td> <td>1/26/15 11:12</td> <td>OM2TCN                                </td> <td>2015-00004887  </td> <td>Traffic           </td> <td>37.857428  </td> <td>-122.2682845</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1900 SAN PABLO AVE, BERKELEY, CA                           </td> <td>1/26/15 12:35</td> <td>BM2RCN                                </td> <td>2015-00004902  </td> <td>Pedestrian        </td> <td>37.870206  </td> <td>-122.292806 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>TELEGRAPH AVE AND DURANT AVE, BERKELEY, CA                 </td> <td>1/26/15 12:51</td> <td>WF2TCN                                </td> <td>2015-00004904  </td> <td>Traffic           </td> <td>37.867814  </td> <td>-122.2589767</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DELAWARE ST AND ACTON ST, BERKELEY, CA                     </td> <td>1/26/15 12:53</td> <td>WM4TCN                                </td> <td>2015-00004905  </td> <td>Traffic           </td> <td>37.8727601 </td> <td>-122.2846144</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>UNIVERSITY AVE AND SHATTUCK AVE, BERKELEY, CA              </td> <td>1/26/15 13:04</td> <td>WM2RCN                                </td> <td>2015-00004909  </td> <td>Pedestrian        </td> <td>37.8721732 </td> <td>-122.2678009</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>SHATTUCK AVE AND UNIVERSITY AVE, BERKELEY, CA              </td> <td>1/26/15 13:16</td> <td>BM4RCN                                </td> <td>2015-00004911  </td> <td>Pedestrian        </td> <td>37.8721732 </td> <td>-122.2678009</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>MARTIN LUTHER KING JR WAY AND CARLETON ST, BERKELEY, CA    </td> <td>1/26/15 13:30</td> <td>WM3TCN                                </td> <td>2015-00004915  </td> <td>Traffic           </td> <td>37.8606384 </td> <td>-122.271792 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2100 SHATTUCK AVE, BERKELEY, CA                            </td> <td>1/26/15 13:30</td> <td>BF3RCN                                </td> <td>2015-00004916  </td> <td>Pedestrian        </td> <td>37.8711217 </td> <td>-122.2682972</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DWIGHT WAY AND SHATTUCK AVE, BERKELEY, CA                  </td> <td>1/26/15 13:48</td> <td>OM2TCN                                </td> <td>2015-00004920  </td> <td>Traffic           </td> <td>37.8639703 </td> <td>-122.2674259</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2400 TELEGRAPH AVE, BERKELEY, CA                           </td> <td>1/26/15 13:54</td> <td>WM2RWN                                </td> <td>2015-00004921  </td> <td>Pedestrian        </td> <td>37.8674642 </td> <td>-122.2594219</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DWIGHT WAY AND ELLSWORTH ST, BERKELEY, CA                  </td> <td>1/26/15 13:59</td> <td>OF2TCN                                </td> <td>2015-00004922  </td> <td>Traffic           </td> <td>37.8645391 </td> <td>-122.2629878</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2400 TELEGRAPH AVE, BERKELEY, CA                           </td> <td>1/26/15 14:03</td> <td>WM2RWN                                </td> <td>2015-00004925  </td> <td>Pedestrian        </td> <td>37.8674642 </td> <td>-122.2594219</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2500 DWIGHT WAY, BERKELEY, CA                              </td> <td>1/26/15 14:14</td> <td>WM4RWN                                </td> <td>2015-00004929  </td> <td>Pedestrian        </td> <td>37.8651228 </td> <td>-122.2584226</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ASHBY AVE AND SHATTUCK AVE, BERKELEY, CA                   </td> <td>1/26/15 14:15</td> <td>OM4TCN                                </td> <td>2015-00004930  </td> <td>Traffic           </td> <td>37.8552946 </td> <td>-122.2665022</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>DERBY ST AND HILLEGASS AVE, BERKELEY, CA                   </td> <td>1/26/15 14:23</td> <td>WM4RON                                </td> <td>2015-00004931  </td> <td>Pedestrian        </td> <td>37.8616548 </td> <td>-122.2559951</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1400 SHATTUCK AVE, BERKELEY, CA                            </td> <td>1/26/15 14:30</td> <td>WM4ICN                                </td> <td>2015-00004932  </td> <td>Pedestrian        </td> <td>37.8818044 </td> <td>-122.2697908</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ASHBY AVE AND SAN PABLO AVE, BERKELEY, CA                  </td> <td>1/26/15 14:35</td> <td>OM3TCN                                </td> <td>2015-00004935  </td> <td>Traffic           </td> <td>37.8521407 </td> <td>-122.286737 </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>SAN PABLO AVE AND FOLGER AVE, BERKELEY, CA                 </td> <td>1/26/15 14:45</td> <td>M                                     </td> <td>2015-00004938  </td> <td>Suspicious Vehicle</td> <td>37.8509635 </td> <td>-122.2862931</td>
#         </

# %%
# Mapping overall data
BERKELEY_LAT = 37.8700
BERKELEY_LONG = -122.2590
RACES = ['A', 'B', 'H', 'O', 'W']
COLORS = ['#1F77B4', '#FF7F0E', '#2CA02C', '#8C564B', '#9467BD']
#          blue,      orange,    green,     brown,       purple

def mark_races_on_map(outputfile, table, folium_map, marker_rad):
    for row in table.rows:
        popup_msg = row.date + '<br />' + row.incident_type + '<br />' + row.dispositions
#         folium_map.simple_marker([row.lat, row.long], popup=popup_msg) # To use default image marker
        color = '#808080' # marker color by default
        if len(row.dispositions) >= 5:
            first_char = row.dispositions[0]
            if first_char in RACES:
                race_index = RACES.index(first_char)
                color = COLORS[race_index]
            else:
    #         Incident disposition wasn't completely reported.
                continue
        else:
    #         Incident disposition wasn't completely reported.
            continue
        folium_map.circle_marker([row.lat, row.long],
                                   radius=marker_rad,
                                   line_color=color,
                                   fill_color=color,
                                   popup=popup_msg) # Colored marker
    folium_map.create_map(path=outputfile)

map_overall = folium.Map(location=[BERKELEY_LAT, BERKELEY_LONG], tiles='Stamen Terrain', zoom_start=14)
mark_races_on_map('berkeley_stop_map_overall.html', sub_table, map_overall, 20)

# %%
# Grouping data by incident type
types = ['Traffic', 'Pedestrian', 'Suspicious Vehicle', 'Bicycle']
tables = []
maps = []
for t in types:
    tab = sub_table.where('incident_type', value=t)
    tables.append(tab)
    m = folium.Map(location=[BERKELEY_LAT, BERKELEY_LONG], tiles='Stamen Terrain', zoom_start=14)
    maps.append(m)

# %%
# Mapping each group
for i in range(len(types)):
    t = types[i]
    tab = tables[i]
    m = maps[i]
    mark_races_on_map('berkeley_stop_map_' + t +'.html', tab, m, 20)
